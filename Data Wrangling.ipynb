# %% [markdown]
# Data Gathering, Data Assessing, Data Cleaning

# %%
import pandas as pd

# %%
df= pd.read_csv("assignment.csv")

# %%
df
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'IMBD title ID', 'Original titlÊ', 'Release year',
#        'Genrë¨', 'Duration', 'Country', 'Content Rating', 'Director',
#        'Unnamed: 8', 'Income', ' Votes ', 'Score'],
#       dtype='object')

# %%
df
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
 df = df.drop(columns=[df.columns[9]])

# %%
df
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# ...

# %%
new = df["imbd title id"].str.split("tt", n = 1, expand = True)

# %%
df
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# ...

# %%
df
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0   [, 0111161]     The Shawshank Redemption    1995-02-10
# 1             1   [, 0068646]                The Godfather    09 21 1972
# 2             2   [, 0468569]              The Dark Knight   23 -07-2008
# 3             3   [, 0071562]       The Godfather: Part II    1975-09-25
# 4             4   [, 0110912]                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96   [, 0070735]                    The Sting    1974-03-21
# 97           97   [, 0082096]                     Das Boot    1982-03-18
# 98           98   [, 0059578]  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99   [, 1832382]      Jodaeiye Nader az Simin    2011-10-21
# 100         100   [, 0045152]          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
# ...

# %%
df_1=df['imbd title id'].str.split('tt', expand=True)

# %%
df_1
# Out:
#     0         1
# 0       0111161
# 1       0068646
# 2       0468569
# 3       0071562
# 4       0110912
# ..  ..      ...
# 96      0070735
# 97      0082096
# 98      0059578
# 99      1832382
# 100     0045152
#
# [101 rows x 2 columns]

# %%
df
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# ...

# %%
df['income'].apply(type).value_counts()
# Out:
# <class 'str'>      100
# <class 'float'>      1
# Name: income, dtype: int64

# %%
df['income_type'] = df['income'].apply(lambda x: type(x).__name__)

# %%
def clean_currency(x):
    """ If the value is a string, then remove currency symbol and delimiters
    otherwise, the value is numeric and can be converted
    """
    if isinstance(x, str):
        return(x.replace('$', '',).replace(',', '',))
    return(x)

# %%
df['income'] = df['income'].apply(clean_currency).astype('float')
df['income_type'] = df['income'].apply(lambda x: type(x).__name__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df['income'] = df['income'].apply(clean_currency).astype('float')
#       2 df['income_type'] = df['income'].apply(lambda x: type(x).__name__)
#
# File D:\cfrbackup-RUDOHEOJ\Backup\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
df['country'] = df['country'].replace('Italy1', 'Italy')

# %%
df.at[df['income'] == '$4o8035783', 'income'] = '$408035783'
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# File D:\cfrbackup-RUDOHEOJ\Backup\Lib\site-packages\pandas\core\frame.py:4211, in DataFrame._set_value(self, index, col, value, takeable)
#    4210     icol = self.columns.get_loc(col)
# -> 4211     iindex = self.index.get_loc(index)
#    4212 self._mgr.column_setitem(icol, iindex, value, inplace=True)
#
# File D:\cfrbackup-RUDOHEOJ\Backup\Lib\site-packages\pandas\core\indexes\range.py:394, in RangeIndex.get_loc(self, key, method, tolerance)
#     393         raise KeyError(key) from err
# --> 394 self._check_indexing_error(key)
#     395 raise KeyError(key)
#
# File D:\cfrbackup-RUDOHEOJ\Backup\Lib\site-packages\pandas\core\indexes\base.py:5925, in Index._check_indexing_error(self, key)
#    5922 if not is_scalar(key):
#    5923     # if key is not a scalar, directly raise an error (the code below
# ...

# %%
df
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration  country content rating  \
# ...
